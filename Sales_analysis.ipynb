# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv("SuperStoreOrders.csv")

# %%
df.head(10)
# Out:
#           order_id order_date ship_date       ship_mode     customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class   Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class       Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class     Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class      Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class       Joseph Holt
# 5    IN-2011-47883   1/1/2011  8/1/2011  Standard Class       Joseph Holt
# 6     CA-2011-1510   2/1/2011  6/1/2011  Standard Class   Magdelene Morse
# 7    IN-2011-79397   3/1/2011  3/1/2011        Same Day       Kean Nguyen
# 8    ID-2011-80230   3/1/2011  9/1/2011  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680   3/1/2011  7/1/2011  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  ...  \
# 0     Consumer      Constantine      Algeria  Africa   Africa  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df['order_date']=pd.to_datetime(df['order_date'],format='mixed', dayfirst=True)  # format = %d-%m-%y

# %%
df['ship_date']=pd.to_datetime(df['ship_date'],format='mixed', dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
# ...

# %%
df.describe()
# Out:
#                           order_date                      ship_date  \
# count                          51290                          51290
# mean   2013-05-11 21:26:49.155780864  2013-05-15 20:42:42.745174528
# min              2011-01-01 00:00:00            2011-01-03 00:00:00
# 25%              2012-06-19 00:00:00            2012-06-23 00:00:00
# 50%              2013-07-08 00:00:00            2013-07-12 00:00:00
# 75%              2014-05-22 00:00:00            2014-05-26 00:00:00
# max              2014-12-31 00:00:00            2015-01-07 00:00:00
# std                              NaN                            NaN
#
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# ...

# %%
df['category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
df['category'].value_counts()
# Out:
# category
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: count, dtype: int64

# %%
df.columns=df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
# negative profit orders
loss_orders = df[df["profit"]<0]
print (loss_orders)

#this prints all the columns but if you want only the negative profit column you add ['profit']
# Out:
#               order_id order_date  ship_date       ship_mode  \
# 3      IT-2011-3647632 2011-01-01 2011-01-05    Second Class
# 8        ID-2011-80230 2011-01-03 2011-01-09  Standard Class
# 10       IN-2011-65159 2011-01-03 2011-01-07    Second Class
# 11       IN-2011-65159 2011-01-03 2011-01-07    Second Class
# 14       ID-2011-80230 2011-01-03 2011-01-09  Standard Class
# ...                ...        ...        ...             ...
# 51267  IT-2014-3715679 2014-12-31 2015-01-05    Second Class
# 51272  IT-2014-3715679 2014-12-31 2015-01-05    Second Class
# 51274     TU-2014-5170 2014-12-31 2015-01-04    Second Class
# 51275    ID-2014-54442 2014-12-31 2015-01-04  Standard Class
# 51289   CA-2014-156720 2014-12-31 2015-01-04  Standard Class
#
#            customer_name      segment             state        country market  \
# 3           Eugene Moren  Home Office         Stockholm         Sweden     EU
# ...

# %%
furniture_profit.head()
# Out:
#            order_id order_date  ship_date       ship_mode      customer_name  \
# 4     IN-2011-47883 2011-01-01 2011-01-08  Standard Class        Joseph Holt
# 9      IZ-2011-4680 2011-01-03 2011-01-07  Standard Class   Lindsay Williams
# 12  ES-2011-4869686 2011-01-03 2011-01-07  Standard Class  Dorothy Dickinson
# 27   MX-2011-111255 2011-01-04 2011-01-09    Second Class  Russell Applegate
# 34   MX-2011-159373 2011-01-04 2011-01-08  Standard Class    Arthur Wiediger
#
#         segment             state         country market     region  ...  \
# 4      Consumer   New South Wales       Australia   APAC    Oceania  ...
# 9     Corporate            Ninawa            Iraq   EMEA       EMEA  ...
# 12     Consumer           England  United Kingdom     EU      North  ...
# 27     Consumer            Parana          Brazil  LATAM      South  ...
# 34  Home Office  Santiago de Cuba            Cuba  LATAM  Caribbean  ...
#
# ...

# %%
df.to_csv("Cleaned_SuperStoreOrders.csv", index=False)
